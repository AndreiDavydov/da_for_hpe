# %%
import torch as th
import matplotlib.pyplot as plt
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
import dataset_loader
dataset = dataset_loader.MPII(mode='train')

# %%
img, joints, _ = dataset[111]

# %%
plt.imshow(img.permute(1,2,0))
plt.plot(joints[:,0], joints[:,1], 'bo')
