# %%
import torch as th
import matplotlib.pyplot as plt
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
import dataset_loader
dataset = dataset_loader.MPII(mode='train', num_images=25000)

# %%
len(dataset)
# Out:
# 14679

# %%
dataset = dataset_loader.MPII(mode='val', num_images=25000)

# %%
len(dataset)
# Out:
# 2729

# %%
img, joints, _ = dataset[555]

# %%
plt.imshow(img.permute(1,2,0))
plt.plot(joints[:,0], joints[:,1], 'bo')
