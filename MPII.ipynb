# %%
import torch as th
import matplotlib.pyplot as plt
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import datasets
dataset = datasets.MPII(mode='train', num_images=100, use_heatmaps=True)

# %%
img, heatmaps, _ = dataset[10]

# %%
plt.imshow(img.permute(1,2,0))
# plt.plot(joints[:,0], joints[:,1], 'bo')

# %%
plt.imshow(heatmaps.sum(dim=0).numpy())
