# %%
from resnet import resnet50
import torch as th

# %%
rn50 = resnet50()
rn50.load_state_dict(th.load('./resnet50.pth'))
# Out:
# <All keys matched successfully>

# %%
import damnet as damnet
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-b8f7f581166f> in <module>
# ----> 1 import damnet as damnet
#
# ModuleNotFoundError: No module named 'damnet'

# %%
for layer, name in zip(layers, rn50.named_children()):
    layer = rn50[name].state_dict()

# %%
resnet_blocks = ['conv1', 'bn1', 'layer1', 'layer2', 'layer3', 'layer4']

# %%
rn50.layer1.state_dict()
# Out:
# OrderedDict([('0.conv1.weight', tensor([[[[ 0.0035]],
#
#                        [[ 0.0399]],
#
#                        [[-0.0248]],
#
#                        ...,
#
#                        [[ 0.1028]],
#
#                        [[-0.2893]],
#
#                        [[-0.1518]]],
#
#
#                       [[[ 0.1149]],
#
#                        [[ 0.0057]],
#
#                        [[ 0.0284]],
#
#                        ...,
#
#                        [[ 0.0807]],
#
#                        [[-0.0848]],
#
#                        [[-0.1358]]],
#
#
#                       [[[-0.0190]],
#
#                        [[ 0.0112]],
#
#                        [[-0.0160]],
#
#                        ...,
#
#                        [[ 0.0715]],
#
#                        [[ 0.0767]],
#
#                        [[-0.0460]]],
#
#
#                       ...,
#
#
#                       [[[-0.0020]],
#
#                        [[-0.0019]],
#
#                        [[ 0.0237]],
#
# ...

# %%
for block in resnet_blocks:
    print(getattr(rn50, block))
    for param in getattr(rn50, block).parameters():
        print(param.size())
    break
# Out:
# Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
# torch.Size([64, 3, 7, 7])

# %%
for param in rn50.layer1.parameters():
    print(param.size())
# Out:
# torch.Size([64, 64, 1, 1])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64, 64, 3, 3])
# torch.Size([64])
# torch.Size([64])
# torch.Size([256, 64, 1, 1])
# torch.Size([256])
# torch.Size([256])
# torch.Size([256, 64, 1, 1])
# torch.Size([256])
# torch.Size([256])
# torch.Size([64, 256, 1, 1])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64, 64, 3, 3])
# torch.Size([64])
# torch.Size([64])
# torch.Size([256, 64, 1, 1])
# torch.Size([256])
# torch.Size([256])
# torch.Size([64, 256, 1, 1])
# torch.Size([64])
# torch.Size([64])
# torch.Size([64, 64, 3, 3])
# torch.Size([64])
# torch.Size([64])
# torch.Size([256, 64, 1, 1])
# torch.Size([256])
# torch.Size([256])
